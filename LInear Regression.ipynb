# %%
cd Downloads
# Out:
# C:\Users\ashok\Downloads

# %%
cd Project
# Out:
# C:\Users\ashok\Downloads\Project

# %%
#Importing all the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

advertising = pd.read_csv( "Football teams.csv" )
advertising.head()

#Importing seaborn library for visualizations
import seaborn as sns

#to plot all the scatterplots in a single plot
sns.pairplot(advertising, x_vars=[ 'Goals', 'Shots pg' , 'yellow_cards' , 'red_cards' , 'Possession%' , 'Pass%' , 'AerialsWon' ], y_vars = 'Rating', height = 5, kind = 'scatter' )
plt.show()


#To plot heatmap to find out correlations
sns.heatmap( advertising.corr(), cmap = 'GnBu', annot = True )
plt.show()

X = advertising[ 'Goals' ]
y = advertising[ 'Rating' ]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, train_size = 0.7, test_size = 0.3, random_state = 100 )


print( X_train.shape )
print( X_test.shape )
print( y_train.shape )
print( y_test.shape )

import statsmodels.api as sm

# Add a constant to get an intercept
X_train_sm = sm.add_constant(X_train)
# Fit the resgression line using 'OLS'
lr = sm.OLS(y_train, X_train_sm).fit()

# Print the parameters,i.e. intercept and slope of the regression line obtained
lr.params

#Performing a summary operation lists out all different parameters of the regression line fitted
print(lr.summary())




# Add a constant to X_test
X_test_sm = sm.add_constant(X_test)
# Predict the y values corresponding to X_test_sm
y_pred = lr.predict(X_test_sm)

y_pred.head()


#Imporitng libraries
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
#R-squared value
r2_score( y_test, y_pred )
# Out:
# (68,)
# (30,)
# (68,)
# (30,)
#                             OLS Regression Results
# ...
# Dep. Variable:                 Rating   R-squared:                       0.718
# Model:                            OLS   Adj. R-squared:                  0.714
# Method:                 Least Squares   F-statistic:                     168.0
# Date:                Tue, 13 Dec 2022   Prob (F-statistic):           8.34e-20
# Time:                        20:22:29   Log-Likelihood:                 83.020
# No. Observations:                  68   AIC:                            -162.0
# Df Residuals:                      66   BIC:                            -157.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.2963      0.028    224.890      0.000       6.240       6.352
# ...

# %%
cd Downloads/Project/
# Out:
# [WinError 3] The system cannot find the path specified: 'Downloads/Project/'
# C:\Users\ashok\Downloads\Project

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error , explained_variance_score , r2_score

#Predicting the testing data 

LL_svr = LinearRegression().fit(X_train,y_train)
print(LL_svr.score(X_train , y_train))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 5>()
#       1 from sklearn.metrics import mean_absolute_error , mean_squared_error , explained_variance_score , r2_score
#       3 #Predicting the testing data
# ----> 5 LL_svr = LinearRegression().fit(X_train,y_train)
#       6 print(LL_svr.score(X_train , y_train))
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# ...

# %%
ytest_pred = LL_sv.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 ytest_pred = LL_svr.predict(X_test)
#
# NameError: name 'LL_svr' is not defined
